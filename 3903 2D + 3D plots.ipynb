# %%
#(this will take a few minutes to install all the dependences!)
# !pip install deeplabcut
#!pip install git+https://github.com/DeepLabCut/DeepLabCut.git
# !pip install --upgrade scikit-image
# %reload_ext numpy
# %reload_ext scipy
# %reload_ext matplotlib
# %reload_ext mpl_toolkits

# !pip install git+https://github.com/aleju/imgaug.git
# Out:
# Requirement already satisfied: deeplabcut in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: ipython in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (7.31.1)
# Requirement already satisfied: imgaug>=0.4.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (0.4.0)
# Requirement already satisfied: pyyaml in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (6.0)
# Requirement already satisfied: tensorflow>=2.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (2.9.1)
# Requirement already satisfied: ruamel.yaml>=0.15.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (0.17.21)
# Requirement already satisfied: numba>=0.54 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (0.55.2)
# Requirement already satisfied: statsmodels!=0.13.2,>=0.11 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (0.13.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.22.3)
# Requirement already satisfied: tables>=3.7.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (3.7.0)
# Requirement already satisfied: matplotlib>=3.3 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (3.5.2)
# Requirement already satisfied: Pillow>=7.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (9.1.1)
# Requirement already satisfied: tf-slim>=1.1.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.1.0)
# Requirement already satisfied: pandas>=1.0.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.4.2)
# Requirement already satisfied: networkx>=2.6 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (2.8.4)
# Requirement already satisfied: scipy>=1.4 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.8.1)
# Requirement already satisfied: filterpy>=1.4.4 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.4.5)
# Requirement already satisfied: tensorpack>=0.11 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (0.11)
# Requirement already satisfied: scikit-learn>=1.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (1.1.1)
# Collecting scikit-image<=0.18.1,>=0.17
#   Using cached scikit_image-0.18.1-cp39-cp39-manylinux1_x86_64.whl (28.9 MB)
# Requirement already satisfied: tqdm in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from deeplabcut) (4.64.0)
# Requirement already satisfied: six in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut) (1.16.0)
# Requirement already satisfied: opencv-python in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut) (4.6.0.66)
# Requirement already satisfied: Shapely in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut) (1.8.2)
# Requirement already satisfied: imageio in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut) (2.19.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut) (21.3)
# Requirement already satisfied: setuptools in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from numba>=0.54->deeplabcut) (58.0.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from numba>=0.54->deeplabcut) (0.38.1)
# Requirement already satisfied: pytz>=2020.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from pandas>=1.0.1->deeplabcut) (2022.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ruamel.yaml>=0.15.0->deeplabcut) (0.2.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image<=0.18.1,>=0.17->deeplabcut) (2022.5.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image<=0.18.1,>=0.17->deeplabcut) (1.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-learn>=1.0->deeplabcut) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-learn>=1.0->deeplabcut) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from statsmodels!=0.13.2,>=0.11->deeplabcut) (0.5.2)
# Requirement already satisfied: numexpr>=2.6.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tables>=3.7.0->deeplabcut) (2.8.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (0.26.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.46.3)
# Requirement already satisfied: wrapt>=1.11.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.1.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (2.9.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (3.19.4)
# Requirement already satisfied: astunparse>=1.6.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (3.10.0.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (0.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorflow>=2.0->deeplabcut) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.0->deeplabcut) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (2.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (2.1.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (2.28.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (2022.5.18.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0->deeplabcut) (3.2.0)
# Requirement already satisfied: msgpack-numpy>=0.4.4.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut) (0.4.8)
# Requirement already satisfied: tabulate>=0.7.7 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut) (0.8.9)
# Requirement already satisfied: pyzmq>=16 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut) (22.3.0)
# Requirement already satisfied: psutil>=5 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut) (5.9.1)
# Requirement already satisfied: msgpack>=0.5.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut) (1.0.4)
# Requirement already satisfied: pickleshare in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (0.1.2)
# Requirement already satisfied: decorator in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (3.0.20)
# Requirement already satisfied: traitlets>=4.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (5.1.1)
# Requirement already satisfied: pygments in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (2.11.2)
# Requirement already satisfied: backcall in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from ipython->deeplabcut) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from jedi>=0.16->ipython->deeplabcut) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from pexpect>4.3->ipython->deeplabcut) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->deeplabcut) (0.2.5)
# Installing collected packages: scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# Successfully installed scikit-image-0.18.1
# Requirement already satisfied: scikit-image in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (0.18.1)
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Requirement already satisfied: scipy>=1.4.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (1.8.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (2022.5.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (9.1.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (1.22.3)
# Requirement already satisfied: packaging>=20.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image) (2.19.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.4)
# Installing collected packages: scikit-image
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.1
#     Uninstalling scikit-image-0.18.1:
#       Successfully uninstalled scikit-image-0.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deeplabcut 2.2.1 requires scikit-image<=0.18.1,>=0.17, but you have scikit-image 0.19.3 which is incompatible.
# Successfully installed scikit-image-0.19.3
# Collecting git+https://github.com/aleju/imgaug.git
#   Cloning https://github.com/aleju/imgaug.git to /tmp/pip-req-build-q6nsn61g
#   Running command git clone -q https://github.com/aleju/imgaug.git /tmp/pip-req-build-q6nsn61g
#   Resolved https://github.com/aleju/imgaug.git to commit 0101108d4fed06bc5056c4a03e2bcb0216dac326
# Requirement already satisfied: six in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (1.22.3)
# Requirement already satisfied: scipy in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (1.8.1)
# Requirement already satisfied: Pillow in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (9.1.1)
# Requirement already satisfied: matplotlib in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (3.5.2)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (0.19.3)
# Requirement already satisfied: opencv-python in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (4.6.0.66)
# Requirement already satisfied: Shapely in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (1.8.2)
# Requirement already satisfied: imageio in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from imgaug==0.4.0) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2.8.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from scikit-image>=0.14.2->imgaug==0.4.0) (2022.5.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from packaging>=20.0->scikit-image>=0.14.2->imgaug==0.4.0) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib->imgaug==0.4.0) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib->imgaug==0.4.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib->imgaug==0.4.0) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mclea2ll-local/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages (from matplotlib->imgaug==0.4.0) (2.8.2)

# %%
# Importing the toolbox (takes several seconds) 

import pandas as pd
from pathlib import Path
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
#CHANGE 'video' and 'DLCscorer' based on the video analysis you want to plot
#CHANGE 'bpt' if you would like to analyze a different body part
#CHANGE 'Dataframe' to read into the absolute path of your video in "_filtered.h5" format
video='snrbaseline_3903_f_Trial1.mp4'

DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'

#dataname = str(Path(video).stem) + DLCscorer + '.h5'

bpt = 'snout'

#loading output of DLC

Dataframe = pd.read_hdf('/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrbaseline_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5')

# %%
#Removes the weird tail of 0.000000 values. Don't worry, it won't mess anything up - see the last frame
#  with real data and compare the index.
Dataframe = Dataframe[Dataframe[DLCscorer][bpt]['likelihood'] != 0]

Dataframe
# Out:
# scorer    DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000             \
# bodyparts                                                      tl
# coords                                                          x          y
# 0                                                1101.175049       45.162491
# 1                                                1101.175049       45.162491
# 2                                                1101.175049       45.162491
# 3                                                 296.164246       39.299973
# 4                                                 295.424683       38.989437
# ...                                                      ...             ...
# 45015                                              22.823471       31.895466
# 45016                                              22.980249       32.031223
# 45017                                             293.307190       38.845886
# 45018                                             293.307190       38.845886
# 45019                                             293.307190       38.845886
#
# scorer                                                               \
# bodyparts                      tr                                bl
# coords    likelihood            x          y likelihood           x
# 0           0.017579  1101.304932  47.094608   0.799862  294.142059
# 1           0.022425  1101.304932  47.407497   0.943960  294.142059
# 2           0.020505  1101.304932  47.696175   0.951451  294.310486
# 3           0.016805  1101.304932  47.873531   0.969942  294.332184
# 4           0.225870  1101.179810  47.995899   0.969264  294.332184
# ...              ...          ...        ...        ...         ...
# 45015       0.085373  1101.403442  47.358635   0.991163  296.750977
# 45016       0.105259  1101.445679  47.294197   0.988206  296.750977
# 45017       0.230599  1101.462280  47.294197   0.994944  296.750977
# 45018       0.128324  1101.462280  47.226101   0.994203  295.965027
# 45019       0.375554  1101.445679  47.201126   0.994369  295.778961
#
# scorer                                         ...                           \
# bodyparts                                  br  ... left_backpaw   tail_base
# coords              y likelihood            x  ...   likelihood           x
# 0          680.569336   0.166631  1091.525269  ...     0.918647  530.856262
# 1          680.569336   0.810377  1091.525269  ...     0.872324  530.856262
# 2          680.569336   0.960209  1091.525269  ...     0.767691  530.856262
# 3          680.247498   0.991447  1091.063965  ...     0.805490  529.737000
# 4          679.377686   0.997116  1089.663696  ...     0.900847  528.688171
# ...               ...        ...          ...  ...          ...         ...
# 45015      678.864502   0.999280  1090.089355  ...     0.178509  914.141724
# 45016      678.864502   0.998444  1090.002319  ...     0.168952  886.810303
# 45017      679.340942   0.996607  1090.207153  ...     0.999698  297.439941
# 45018      679.340942   0.998451  1090.002319  ...     0.999909  297.346588
# 45019      679.340942   0.998930  1089.910400  ...     0.998945  297.346588
#
# scorer                                                               \
# bodyparts                           tail_mid
# coords              y likelihood           x           y likelihood
# 0          184.834503   0.999536   98.198761  231.169052   0.096927
# 1          185.951538   0.999818  133.833893  236.153458   0.013623
# 2          185.951538   0.999769  555.771423  236.153458   0.004675
# 3          185.951538   0.997774  551.256348  236.153458   0.136595
# 4          179.917816   0.998958  551.256348  230.474121   0.870728
# ...               ...        ...         ...         ...        ...
# 45015      283.549194   0.987030  965.150208  241.131760   0.747705
# 45016      286.344360   0.240043  959.393311  235.055878   0.057370
# 45017       51.217419   0.253244  297.744415   56.072670   0.050512
# 45018       49.052544   0.930925  297.484894   55.036671   0.779856
# 45019       48.902142   0.142326  290.751129   53.584137   0.025375
#
# scorer
# bodyparts     tailtip
# coords              x           y likelihood
# 0           63.058857  694.797241   0.362151
# 1           63.881126  694.797241   0.806522
# 2           64.329521  694.797241   0.535752
# 3           64.923775  694.774414   0.680993
# 4           64.923775  694.774414   0.776794
# ...               ...         ...        ...
# 45015      995.959778  187.778961   0.984954
# 45016       65.431335  694.395142   0.596789
# 45017       65.431335  694.395142   0.502367
# 45018       65.423180  694.395142   0.520027
# 45019       64.861115  694.172791   0.435249
#
# [45020 rows x 42 columns]

# %%
import math

fps = 25
fpm = fps * 60
numFramesTotal = len(Dataframe.index)
minutesTotal = math.floor(numFramesTotal / fpm) #gets number of minutes in the video, rounded down to plot each one

ten_min_increments = minutesTotal / 10

numColumns = 2

numRows = math.ceil(ten_min_increments / numColumns)

# If you want to "zoom in" on the mouse in each time interval, set sharex=False, sharey=False
# For equal scaling in all subplots, set sharex=True, sharey=True
fig, axs = plt.subplots(numRows, numColumns, sharex=False, sharey=False, figsize=(16,16)) 
plt.xlim(0, 1200)
plt.ylim(0, 800)

lowIndex = 0
highIndex = fpm
for n, ax in enumerate(axs.flatten()):
  subDf = Dataframe[lowIndex:highIndex]
  sub_xsnout = subDf[DLCscorer][bpt]['x'].values
  sub_ysnout = subDf[DLCscorer][bpt]['y'].values

  ax.scatter(sub_xsnout,sub_ysnout, s=5, c=subDf.index.values, cmap='plasma')
  plt.gca().invert_yaxis()

  lowIndex += fpm
  highIndex += fpm

for a in fig.axes:
    a.tick_params(
    axis='both',           # changes apply to the x-axis
    which='both',       # both major and minor ticks are affected
    bottom=True,
    top=False,
    left=True,
    right=False,
    labelleft=True,
    labelbottom=True)    # labels along the bottom edge are on
    
    
plt.show()

#BASELINE IS SHOWN BELOW

# %%
video='snrffz_3903_f_Trial1.mp4'

DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'

#dataname = str(Path(video).stem) + DLCscorer + '.h5'

bpt = 'snout'

#loading output of DLC

Dataframe = pd.read_hdf('/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrffz_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5')

# %%
Dataframe = Dataframe[Dataframe[DLCscorer][bpt]['likelihood'] != 0]

Dataframe
# Out:
# scorer    DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000             \
# bodyparts                                                      tl
# coords                                                          x          y
# 0                                                  22.669004       31.896017
# 1                                                  22.719198       31.912050
# 2                                                  22.719198       31.912050
# 3                                                  22.719198       31.912050
# 4                                                  22.842560       32.223442
# ...                                                      ...             ...
# 135056                                            866.680664       -2.624710
# 135057                                            866.680664       -2.544650
# 135059                                            867.677612       -3.081278
# 135060                                            867.677612       -2.544650
# 135061                                            867.677612       -2.544650
#
# scorer                                                               \
# bodyparts                      tr                                bl
# coords    likelihood            x          y likelihood           x
# 0           0.022809  1100.995972  46.879566   0.976413  295.147949
# 1           0.059915  1101.359253  47.195026   0.969554  295.233246
# 2           0.057055  1101.359253  47.273808   0.969118  295.953949
# 3           0.052648  1101.421387  47.273808   0.974323  295.953949
# 4           0.054361  1101.458496  47.238796   0.985813  295.953949
# ...              ...          ...        ...        ...         ...
# 135056      0.037759   466.552277   0.302518   0.048185    1.805172
# 135057      0.079953   466.552277   0.514263   0.090978    1.805172
# 135059      0.112937   707.723450   0.251531   0.035439    2.119035
# 135060      0.057171   707.723450   0.000000   0.049025    2.119035
# 135061      0.077584   707.723450   0.000000   0.033283    2.119035
#
# scorer                                         ...                           \
# bodyparts                                  br  ... left_backpaw   tail_base
# coords              y likelihood            x  ...   likelihood           x
# 0          680.670288   0.990481  1089.786743  ...     0.999584  337.956024
# 1          680.670288   0.993367  1090.171753  ...     0.992283  337.956024
# 2          680.670288   0.994150  1090.171753  ...     0.703118  337.956024
# 3          680.567261   0.998247  1089.856201  ...     0.781216  329.184143
# 4          680.058411   0.998377  1089.856201  ...     0.174061  329.184143
# ...               ...        ...          ...  ...          ...         ...
# 135056     724.811584   0.000928   550.198425  ...     0.918554  225.680893
# 135057     724.904236   0.001049   551.928711  ...     0.931808  213.543259
# 135059     724.985657   0.001078   551.122192  ...     0.940311  213.543259
# 135060     724.985657   0.000935   551.042786  ...     0.916866  207.592575
# 135061     724.985657   0.000878   551.042786  ...     0.829548  207.592575
#
# scorer                                                               \
# bodyparts                           tail_mid
# coords              y likelihood           x           y likelihood
# 0          504.424774   0.999286  372.218231  589.113708   0.996406
# 1          504.424774   0.998924  372.218231  589.113708   0.997067
# 2          504.424774   0.973580  372.218231  589.113708   0.807612
# 3          484.808044   0.954454  328.088440  559.113953   0.033471
# 4          473.936920   0.999714  325.352661  550.496094   0.983115
# ...               ...        ...         ...         ...        ...
# 135056     103.471680   0.174486  550.716064    1.507787   0.089968
# 135057     104.811142   0.069237  550.350708    1.507787   0.175897
# 135059     119.721825   0.065348  550.716064    1.818791   0.276192
# 135060     119.721825   0.033659  550.350708    1.150323   0.266623
# 135061     119.721825   0.087030  550.350708    1.150323   0.142725
#
# scorer
# bodyparts     tailtip
# coords              x           y likelihood
# 0           65.222885  693.969116   0.433901
# 1           65.735756  693.969116   0.546275
# 2           65.857460  693.969116   0.664850
# 3           65.735756  693.969116   0.727858
# 4           65.735756  693.969116   0.997349
# ...               ...         ...        ...
# 135056     761.836426  214.743652   0.226282
# 135057     547.786011   46.129608   0.404011
# 135059     549.131897   45.926617   0.005520
# 135060     547.786011   15.763261   0.010318
# 135061     547.786011   15.763261   0.008840
#
# [121915 rows x 42 columns]

# %%
import math

fps = 25
fpm = fps * 60
numFramesTotal = len(Dataframe.index)
minutesTotal = math.floor(numFramesTotal / fpm) #gets number of minutes in the video, rounded down to plot each one

ten_min_increments = minutesTotal / 10

numColumns = 2

numRows = math.ceil(ten_min_increments / numColumns)

# If you want to "zoom in" on the mouse in each time interval, set sharex=False, sharey=False
# For equal scaling in all subplots, set sharex=True, sharey=True
fig, axs = plt.subplots(numRows, numColumns, sharex=False, sharey=False, figsize=(16,16)) 
plt.xlim(0, 1200)
plt.ylim(0, 800)

lowIndex = 0
highIndex = fpm
for n, ax in enumerate(axs.flatten()):
  subDf = Dataframe[lowIndex:highIndex]
  sub_xsnout = subDf[DLCscorer][bpt]['x'].values
  sub_ysnout = subDf[DLCscorer][bpt]['y'].values

  ax.scatter(sub_xsnout,sub_ysnout, s=5, c=subDf.index.values, cmap='plasma')
  plt.gca().invert_yaxis()

  lowIndex += fpm
  highIndex += fpm

for a in fig.axes:
    a.tick_params(
    axis='both',           # changes apply to the x-axis
    which='both',       # both major and minor ticks are affected
    bottom=True,
    top=False,
    left=True,
    right=False,
    labelleft=True,
    labelbottom=True)    # labels along the bottom edge are on
    
    
plt.show()

#FFZ IS SHOWN BELOW

# %%
hdf_path = '/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrbaseline_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5'
Dataframe = pd.read_hdf(hdf_path)

DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'
bpt = 'snout'

x_snout = Dataframe[DLCscorer][bpt]['x'].values
y_snout = Dataframe[DLCscorer][bpt]['y'].values

from mpl_toolkits.mplot3d import proj3d

def make_get_proj(self, rx, ry, rz):
    '''
    Return a variation on :func:`~mpl_toolkit.mplot2d.axes3d.Axes3D.getproj` that
    makes the box aspect ratio equal to *rx:ry:rz*, using an axes object *self*.
    '''

    rm = max(rx, ry, rz)
    kx = rm / rx; ky = rm / ry; kz = rm / rz;

    # Copied directly from mpl_toolkit/mplot3d/axes3d.py. New or modified lines are
    # marked by ##
    def get_proj():
        relev, razim = np.pi * self.elev/180, np.pi * self.azim/180

        xmin, xmax = self.get_xlim3d()
        ymin, ymax = self.get_ylim3d()
        zmin, zmax = self.get_zlim3d()

        # transform to uniform world coordinates 0-1.0,0-1.0,0-1.0
        worldM = proj3d.world_transformation(xmin, xmax,
                                             ymin, ymax,
                                             zmin, zmax)

        # adjust the aspect ratio                          ##
        aspectM = proj3d.world_transformation(-kx + 1, kx, ##
                                              -ky + 1, ky, ##
                                              -kz + 1, kz) ##

        # look into the middle of the new coordinates
        R = np.array([0.5, 0.5, 0.5])

        xp = R[0] + np.cos(razim) * np.cos(relev) * self.dist
        yp = R[1] + np.sin(razim) * np.cos(relev) * self.dist
        zp = R[2] + np.sin(relev) * self.dist
        E = np.array((xp, yp, zp))

        self.eye = E
        self.vvec = R - E
        self.vvec = self.vvec / proj3d.mod(self.vvec)

        if abs(relev) > np.pi/2:
            # upside down
            V = np.array((0, 0, -1))
        else:
            V = np.array((0, 0, 1))
        zfront, zback = -self.dist, self.dist

        viewM = proj3d.view_transformation(E, R, V)
        perspM = proj3d.persp_transformation(zfront, zback)
        M0 = np.dot(viewM, np.dot(aspectM, worldM)) ##
        M = np.dot(perspM, M0)
        return M
    return get_proj

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

ax.scatter3D(x_snout, Dataframe.index.values, y_snout, s=2, c= Dataframe.index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')


ax.set_box_aspect(((x_snout.max() - x_snout.min()), 5000, (y_snout.max() - y_snout.min())))

#BASELINE IS SHOWN BELOW

# %%
hdf_path = '/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrbaseline_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5'
Dataframe = pd.read_hdf(hdf_path)

DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'
bpt = 'snout'

x_snout = Dataframe[DLCscorer][bpt]['x'].values
y_snout = Dataframe[DLCscorer][bpt]['y'].values

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[0:15000]
ysnout10min = y_snout[0:15000]

ax.scatter3D(xsnout10min, Dataframe[0:15000].index.values, ysnout10min, s=2, c= Dataframe[0:15000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[15000:30000]
ysnout10min = y_snout[15000:30000]

ax.scatter3D(xsnout10min, Dataframe[15000:30000].index.values, ysnout10min, s=2, c= Dataframe[15000:30000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[30000:45000]
ysnout10min = y_snout[30000:45000]

ax.scatter3D(xsnout10min, Dataframe[30000:45000].index.values, ysnout10min, s=2, c= Dataframe[30000:45000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[45000:60000]
ysnout10min = y_snout[45000:60000]

ax.scatter3D(xsnout10min, Dataframe[45000:60000].index.values, ysnout10min, s=2, c= Dataframe[45000:60000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[60000:75000]
ysnout10min = y_snout[60000:75000]

ax.scatter3D(xsnout10min, Dataframe[60000:75000].index.values, ysnout10min, s=2, c= Dataframe[60000:75000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[75000:90000]
ysnout10min = y_snout[75000:90000]

ax.scatter3D(xsnout10min, Dataframe[75000:90000].index.values, ysnout10min, s=2, c= Dataframe[75000:90000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[90000:105000]
ysnout10min = y_snout[90000:105000]

ax.scatter3D(xsnout10min, Dataframe[90000:105000].index.values, ysnout10min, s=2, c= Dataframe[90000:105000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[105000:120000]
ysnout10min = y_snout[105000:120000]

ax.scatter3D(xsnout10min, Dataframe[105000:120000].index.values, ysnout10min, s=2, c= Dataframe[105000:120000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[120000:135000]
ysnout10min = y_snout[120000:135000]

ax.scatter3D(xsnout10min, Dataframe[120000:135000].index.values, ysnout10min, s=2, c= Dataframe[120000:135000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

#BASELINE IS SHOWN BELOW
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_296237/3629789653.py in <module>
#      67 ax.set_zlabel('y (pixels)')
#      68
# ---> 69 ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))
#      70
#      71 fig = plt.figure(figsize=(10,10))
#
# ~/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      41
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
hdf_path = '/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrround2ffz_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5'
Dataframe = pd.read_hdf(hdf_path)

DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'
bpt = 'snout'

x_snout = Dataframe[DLCscorer][bpt]['x'].values
y_snout = Dataframe[DLCscorer][bpt]['y'].values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_296237/359735088.py in <module>
#       1 hdf_path = '/home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrround2ffz_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5'
# ----> 2 Dataframe = pd.read_hdf(hdf_path)
#       3
#       4 DLCscorer='DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000'
#       5 bpt = 'snout'
#
# ~/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     425
#     426         if not exists:
# --> 427             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     428
#     429         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#
# FileNotFoundError: File /home/mclea2ll-local/Documents/DeepLabCut/Video_Analysis/SNR_LMO7_turning_Lily/snrround2ffz_3903_f_Trial1DLC_resnet50_Pilot_v1_single_animalJun29shuffle1_400000_filtered.h5 does not exist

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[0:15000]
ysnout10min = y_snout[0:15000]

ax.scatter3D(xsnout10min, Dataframe[0:15000].index.values, ysnout10min, s=2, c= Dataframe[0:15000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[15000:30000]
ysnout10min = y_snout[15000:30000]

ax.scatter3D(xsnout10min, Dataframe[15000:30000].index.values, ysnout10min, s=2, c= Dataframe[15000:30000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[30000:45000]
ysnout10min = y_snout[30000:45000]

ax.scatter3D(xsnout10min, Dataframe[30000:45000].index.values, ysnout10min, s=2, c= Dataframe[30000:45000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[45000:60000]
ysnout10min = y_snout[45000:60000]

ax.scatter3D(xsnout10min, Dataframe[45000:60000].index.values, ysnout10min, s=2, c= Dataframe[45000:60000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[60000:75000]
ysnout10min = y_snout[60000:75000]

ax.scatter3D(xsnout10min, Dataframe[60000:75000].index.values, ysnout10min, s=2, c= Dataframe[60000:75000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[75000:90000]
ysnout10min = y_snout[75000:90000]

ax.scatter3D(xsnout10min, Dataframe[75000:90000].index.values, ysnout10min, s=2, c= Dataframe[75000:90000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[90000:105000]
ysnout10min = y_snout[90000:105000]

ax.scatter3D(xsnout10min, Dataframe[90000:105000].index.values, ysnout10min, s=2, c= Dataframe[90000:105000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[105000:120000]
ysnout10min = y_snout[105000:120000]

ax.scatter3D(xsnout10min, Dataframe[105000:120000].index.values, ysnout10min, s=2, c= Dataframe[105000:120000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

xsnout10min = x_snout[120000:135000]
ysnout10min = y_snout[120000:135000]

ax.scatter3D(xsnout10min, Dataframe[120000:135000].index.values, ysnout10min, s=2, c= Dataframe[120000:135000].index.values, cmap= 'viridis')
ax.invert_zaxis()
ax.set_xlabel('x (pixels)')
ax.set_ylabel('t')
ax.set_zlabel('y (pixels)')

ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))

#FFZ IS SHOWN BELOW
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_296237/106618601.py in <module>
#      67 ax.set_zlabel('y (pixels)')
#      68
# ---> 69 ax.set_box_aspect(((xsnout10min.max() - xsnout10min.min()), 5000, (ysnout10min.max() - ysnout10min.min())))
#      70
#      71 fig = plt.figure(figsize=(10,10))
#
# ~/.conda/envs/jup_cresp_mclea/lib/python3.9/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      38 def _amax(a, axis=None, out=None, keepdims=False,
#      39           initial=_NoValue, where=True):
# ---> 40     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      41
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity
